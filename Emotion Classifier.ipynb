# %%
# Before proceeding run this cell (but if you have already install then ignore)
# !pip install tensorflow==2.15.0
# !pip install scikit-learn
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotlib
# !pip install wordcloud
# !pip install nltk
# Out:
# Collecting tensorflow==2.15.0
#   Downloading tensorflow-2.15.0-cp39-cp39-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.15.0
#   Downloading tensorflow_intel-2.15.0-cp39-cp39-win_amd64.whl (300.8 MB)
#      ------------------------------------ 300.8/300.8 MB 991.6 kB/s eta 0:00:00
# Collecting tensorflow-estimator<2.16,>=2.15.0
#   Downloading tensorflow_estimator-2.15.0-py2.py3-none-any.whl (441 kB)
#      -------------------------------------- 442.0/442.0 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (15.0.6.1)
# Requirement already satisfied: packaging in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (21.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (63.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.0)
# Collecting keras<2.16,>=2.15.0
#   Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.6.3)
# Collecting ml-dtypes~=0.2.0
#   Downloading ml_dtypes-0.2.0-cp39-cp39-win_amd64.whl (938 kB)
#      -------------------------------------- 938.4/938.4 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.3-cp39-cp39-win_amd64.whl (413 kB)
#      ------------------------------------ 413.4/413.4 kB 992.9 kB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.3.0)
# Collecting tensorboard<2.16,>=2.15
#   Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.31.0)
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting numpy<2.0.0,>=1.23.5
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 15.8/15.8 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\tast\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.51.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\tast\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\tast\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\tast\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3.4)
# Collecting google-auth-oauthlib<2,>=0.5
#   Downloading google_auth_oauthlib-1.2.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\tast\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\tast\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tast\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.0.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tast\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tast\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\tast\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\tast\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tast\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tast\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\tast\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tast\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tast\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\tast\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow==2.15.0) (3.2.2)
# Installing collected packages: flatbuffers, tensorflow-estimator, tensorboard-data-server, protobuf, numpy, keras, ml-dtypes, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.3.3
#     Uninstalling flatbuffers-23.3.3:
#       Successfully uninstalled flatbuffers-23.3.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.11.0
#     Uninstalling tensorflow-intel-2.11.0:
#       Successfully uninstalled tensorflow-intel-2.11.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed flatbuffers-24.3.25 google-auth-oauthlib-1.2.0 keras-2.15.0 ml-dtypes-0.2.0 numpy-1.26.4 protobuf-4.25.3 tensorboard-2.15.2 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# scipy 1.9.1 requires numpy<1.25.0,>=1.18.5, but you have numpy 1.26.4 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.4 which is incompatible.
# Requirement already satisfied: scikit-learn in c:\users\tast\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tast\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\tast\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\tast\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\tast\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting numpy>=1.14.6
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      ---------------------------------------- 14.9/14.9 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.24.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.4 which is incompatible.
# Requirement already satisfied: pandas in c:\users\tast\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tast\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\tast\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tast\anaconda3\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\tast\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\tast\anaconda3\lib\site-packages (1.24.4)
# Requirement already satisfied: seaborn in c:\users\tast\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\tast\anaconda3\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\tast\anaconda3\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\tast\anaconda3\lib\site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\tast\anaconda3\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tast\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\tast\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\tast\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\tast\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#      ------------------------------------ 300.6/300.6 kB 774.2 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\tast\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\tast\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\tast\anaconda3\lib\site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tast\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\tast\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Requirement already satisfied: nltk in c:\users\tast\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\tast\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\tast\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: click in c:\users\tast\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\tast\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\tast\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %% [markdown]
# ## Load Libraries

# %%
# dl packages
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# ml packages
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import pickle
import nltk
import re
from nltk.stem import PorterStemmer

import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud
# Out:
# WARNING:tensorflow:From C:\Users\Tast\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load Data

# %%
train_data = pd.read_csv("train.txt", header=None, sep=";", names=["Comment", "Emotion"], encoding="utf-8")
# get all words length in comment
train_data['length'] = [len(x) for x in train_data['Comment']]

# %%
train_data
# Out:
#                                                  Comment  Emotion  length
# 0                                i didnt feel humiliated  sadness      23
# 1      i can go from feeling so hopeless to so damned...  sadness     108
# 2       im grabbing a minute to post i feel greedy wrong    anger      48
# 3      i am ever feeling nostalgic about the fireplac...     love      92
# 4                                   i am feeling grouchy    anger      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...  sadness     101
# 15996  i am now turning and i feel pathetic that i am...  sadness     102
# 15997                     i feel strong and good overall      joy      30
# 15998  i feel like this was such a rude comment and i...    anger      59
# 15999  i know a lot but i feel so stupid because i ca...  sadness      62
#
# [16000 rows x 3 columns]

# %%
train_data.shape
# Out:
# (16000, 3)

# %%
train_data.isnull().sum()
# Out:
# Comment    0
# Emotion    0
# length     0
# dtype: int64

# %%
train_data.duplicated().sum()
# Out:
# 1

# %%
train_data.drop_duplicates(inplace=True)

# %% [markdown]
# ## EDA

# %%
sns.countplot(x = train_data['Emotion'])
plt.show()

# %%
# data distribution
df2 = train_data.copy()
df2['length'] = [len(x) for x in df2['Comment']]

# %%
# Convert the 'length' column to a numpy array
length_values = df2['length'].values

# Use sns.histplot instead of sns.kdeplot for simplicity
sns.histplot(data=df2, x='length', hue='Emotion', multiple='stack')

plt.show()

# %%
# Words cloud for each emotions
def words_cloud(wordcloud, emotion):
    plt.figure(figsize=(10, 10))
    plt.title(emotion+' Word Cloud', size = 16)
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
emotions_list = train_data['Emotion'].unique()
for emotion in emotions_list:
    text = ' '.join([sentence for sentence in train_data.loc[train_data['Emotion'] == emotion,'Comment']])
    wordcloud = WordCloud(width = 600, height = 600).generate(text)
    words_cloud(wordcloud, emotion)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Encode Emotions

# %%
lb = LabelEncoder()
train_data['Emotion'] = lb.fit_transform(train_data['Emotion'])

# %%
train_data
# Out:
#                                                  Comment  Emotion  length
# 0                                i didnt feel humiliated        4      23
# 1      i can go from feeling so hopeless to so damned...        4     108
# 2       im grabbing a minute to post i feel greedy wrong        0      48
# 3      i am ever feeling nostalgic about the fireplac...        3      92
# 4                                   i am feeling grouchy        0      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...        4     101
# 15996  i am now turning and i feel pathetic that i am...        4     102
# 15997                     i feel strong and good overall        2      30
# 15998  i feel like this was such a rude comment and i...        0      59
# 15999  i know a lot but i feel so stupid because i ca...        4      62
#
# [15999 rows x 3 columns]

# %% [markdown]
# ## Applying Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
df = train_data.copy() # copy df from train_data because we will use this for deep learing next

# %%
df
# Out:
#                                                  Comment  Emotion  length
# 0                                i didnt feel humiliated        4      23
# 1      i can go from feeling so hopeless to so damned...        4     108
# 2       im grabbing a minute to post i feel greedy wrong        0      48
# 3      i am ever feeling nostalgic about the fireplac...        3      92
# 4                                   i am feeling grouchy        0      20
# ...                                                  ...      ...     ...
# 15995  i just had a very brief time in the beanbag an...        4     101
# 15996  i am now turning and i feel pathetic that i am...        4     102
# 15997                     i feel strong and good overall        2      30
# 15998  i feel like this was such a rude comment and i...        0      59
# 15999  i know a lot but i feel so stupid because i ca...        4      62
#
# [15999 rows x 3 columns]

# %%
# Data cleaning and preprocessing
# Download NLTK stopwords
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
def clean_text(text):
    stemmer = PorterStemmer()
    text = re.sub("[^a-zA-Z]", " ", text)
    text = text.lower()
    text = text.split()
    text = [stemmer.stem(word) for word in text if word not in stopwords]
    return " ".join(text)

df['cleaned_comment'] = df['Comment'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tast\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df['cleaned_comment'],df['Emotion'],test_size=0.2,random_state=42)

# %%
# Vectorization using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
# Multi-class classification using different algorithms
classifiers = {
    "Multinomial Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
}

for name, clf in classifiers.items():
    print(f"\n===== {name} =====")
    clf.fit(X_train_tfidf, y_train)
    y_pred_tfidf = clf.predict(X_test_tfidf)
    accuracy_tfidf = accuracy_score(y_test, y_pred_tfidf)
    print(f"\nAccuracy using TF-IDF: {accuracy_tfidf}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred_tfidf))
# Out:
# ===== Multinomial Naive Bayes =====
#
# Accuracy using TF-IDF: 0.6590625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.32      0.48       439
#            1       0.88      0.23      0.37       375
#            2       0.58      0.98      0.73      1027
#            3       1.00      0.03      0.05       303
#            4       0.72      0.91      0.80       950
#            5       1.00      0.02      0.04       106
#
#     accuracy                           0.66      3200
#    macro avg       0.85      0.42      0.41      3200
# weighted avg       0.76      0.66      0.59      3200
#
#
# ===== Logistic Regression =====
# C:\Users\Tast\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy using TF-IDF: 0.8240625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83       439
#            1       0.85      0.72      0.78       375
#            2       0.76      0.94      0.84      1027
#            3       0.83      0.46      0.59       303
#            4       0.88      0.92      0.90       950
#            5       0.74      0.46      0.57       106
#
#     accuracy                           0.82      3200
#    macro avg       0.82      0.71      0.75      3200
# weighted avg       0.83      0.82      0.82      3200
#
#
# ===== Random Forest =====
#
# Accuracy using TF-IDF: 0.8509375
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       439
#            1       0.82      0.84      0.83       375
#            2       0.84      0.90      0.87      1027
#            3       0.83      0.60      0.70       303
#            4       0.92      0.88      0.90       950
#            5       0.70      0.74      0.72       106
#
#     accuracy                           0.85      3200
#    macro avg       0.82      0.81      0.81      3200
# weighted avg       0.85      0.85      0.85      3200
#
#
# ===== Support Vector Machine =====
#
# Accuracy using TF-IDF: 0.815625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       439
#            1       0.84      0.73      0.78       375
#            2       0.75      0.94      0.83      1027
#            3       0.82      0.37      0.51       303
#            4       0.87      0.90      0.89       950
#            5       0.82      0.47      0.60       106
#
#     accuracy                           0.82      3200
#    macro avg       0.83      0.70      0.74      3200
# weighted avg       0.82      0.82      0.80      3200

# %%
# selecting model
lg = LogisticRegression()
lg.fit(X_train_tfidf, y_train)
lg_y_pred = lg.predict(X_test_tfidf)
# Out:
# C:\Users\Tast\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
def predict_emotion(input_text):
    cleaned_text = clean_text(input_text)
    input_vectorized = tfidf_vectorizer.transform([cleaned_text])

    # Predict emotion
    predicted_label = lg.predict(input_vectorized)[0]
    predicted_emotion = lb.inverse_transform([predicted_label])[0]
    label =  np.max(lg.predict(input_vectorized))

    return predicted_emotion,label

# Example usage 
sentences = [
            "i didnt feel humiliated",
            "i feel strong and good overall",
            "im grabbing a minute to post i feel greedy wrong",
            "He was speechles when he found out he was accepted to this new job",
            "This is outrageous, how can you talk like that?",
            "I feel like im all alone in this world",
            "He is really sweet and caring",
            "You made me very crazy",
            "i am ever feeling nostalgic about the fireplace i will know that it is still on the property",
            "i am feeling grouchy",
            "He hates you"
            ]
for sentence in sentences:
    print(sentence)
    pred_emotion, label = predict_emotion(sentence)
    print("Prediction :",pred_emotion)
    print("Label :",label)
    print("================================================================")
# Out:
# i didnt feel humiliated
# Prediction : sadness
# Label : 4
# ================================================================
# i feel strong and good overall
# Prediction : joy
# Label : 2
# ================================================================
# im grabbing a minute to post i feel greedy wrong
# Prediction : anger
# Label : 0
# ================================================================
# He was speechles when he found out he was accepted to this new job
# Prediction : joy
# Label : 2
# ================================================================
# This is outrageous, how can you talk like that?
# Prediction : anger
# Label : 0
# ================================================================
# I feel like im all alone in this world
# Prediction : sadness
# Label : 4
# ================================================================
# He is really sweet and caring
# Prediction : love
# Label : 3
# ================================================================
# You made me very crazy
# Prediction : sadness
# Label : 4
# ================================================================
# i am ever feeling nostalgic about the fireplace i will know that it is still on the property
# Prediction : love
# Label : 3
# ================================================================
# i am feeling grouchy
# Prediction : anger
# Label : 0
# ================================================================
# He hates you
# Prediction : anger
# Label : 0
# ================================================================

# %%
# save files
import pickle
pickle.dump(lg,open("logistic_regresion.pkl",'wb'))
pickle.dump(lb,open("label_encoder.pkl",'wb'))
pickle.dump(tfidf_vectorizer,open("tfidf_vectorizer.pkl",'wb'))

# %%
import sklearn
print(sklearn.__version__) # use this version in pycharm
# Out:
# 1.0.2

# %% [markdown]
# ## Applying Deep Learning Using LSTM

# %% [markdown]
# ## Text Cleaning, Encoding and Padding

# %%
# Text cleaning function
def text_cleaning(df, column, vocab_size, max_len):
    stemmer = PorterStemmer()
    corpus = []

    for text in df[column]:
        text = re.sub("[^a-zA-Z]", " ", text)
        text = text.lower()
        text = text.split()
        text = [stemmer.stem(word) for word in text if word not in stopwords]
        text = " ".join(text)
        corpus.append(text)

    one_hot_word = [one_hot(input_text=word, n=vocab_size) for word in corpus]
    pad = pad_sequences(sequences=one_hot_word, maxlen=max_len, padding='pre')
    return pad

# Text cleaning and encoding
x_train = text_cleaning(train_data, "Comment", vocab_size=11000, max_len=300)
y_train = to_categorical(train_data["Emotion"])

# %% [markdown]
# ## Model Building and Training

# %%
# Build and compile the model
model = Sequential()
model.add(Embedding(input_dim=11000, output_dim=150, input_length=300))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(6, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
callback = EarlyStopping(monitor="val_loss", patience=2, restore_best_weights=True)
model.fit(x_train, y_train, epochs=10, batch_size=64, verbose=1, callbacks=[callback])
# Out:
# WARNING:tensorflow:From C:\Users\Tast\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Tast\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Tast\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Tast\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 250/250 [==============================] - ETA: 0s - loss: 1.4401 - accuracy: 0.4347WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 181s 703ms/step - loss: 1.4401 - accuracy: 0.4347
# Epoch 2/10
# 250/250 [==============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.8068WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 175s 701ms/step - loss: 0.5961 - accuracy: 0.8068
# Epoch 3/10
# 250/250 [==============================] - ETA: 0s - loss: 0.2822 - accuracy: 0.9093WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 175s 701ms/step - loss: 0.2822 - accuracy: 0.9093
# Epoch 4/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9387WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 179s 715ms/step - loss: 0.1856 - accuracy: 0.9387
# Epoch 5/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 178s 712ms/step - loss: 0.1490 - accuracy: 0.9499
# Epoch 6/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9564WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 178s 714ms/step - loss: 0.1228 - accuracy: 0.9564
# Epoch 7/10
# 250/250 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9634WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 178s 714ms/step - loss: 0.1080 - accuracy: 0.9634
# Epoch 8/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0911 - accuracy: 0.9693WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 179s 715ms/step - loss: 0.0911 - accuracy: 0.9693
# Epoch 9/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 178s 713ms/step - loss: 0.0770 - accuracy: 0.9737
# Epoch 10/10
# 250/250 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 250/250 [==============================] - 178s 713ms/step - loss: 0.0658 - accuracy: 0.9781

# %% [markdown]
# ## Predictive System

# %%
# Text cleaning function
def sentence_cleaning(sentence):
    stemmer = PorterStemmer()
    corpus = []
    text = re.sub("[^a-zA-Z]", " ", sentence)
    text = text.lower()
    text = text.split()
    text = [stemmer.stem(word) for word in text if word not in stopwords]
    text = " ".join(text)
    corpus.append(text)
    one_hot_word = [one_hot(input_text=word, n=11000) for word in corpus]
    pad = pad_sequences(sequences=one_hot_word, maxlen=300, padding='pre')
    return pad

# load model and predict 
sentences = [
            "i feel strong and good overall",
            "im grabbing a minute to post i feel greedy wrong",
            "He was speechles when he found out he was accepted to this new job",
            "This is outrageous, how can you talk like that?",
            "I feel like im all alone in this world",
            "He is really sweet and caring",
            "You made me very crazy",
            "i am ever feeling nostalgic about the fireplace i will know that it is still on the property",
            "i am feeling grouchy",
            "He hates you"
            ]
for sentence in sentences:
    print(sentence)
    sentence = sentence_cleaning(sentence)
    result = lb.inverse_transform(np.argmax(model.predict(sentence), axis=-1))[0]
    proba =  np.max(model.predict(sentence))
    print(f"{result} : {proba}\n\n")
# Out:
# i feel strong and good overall
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 67ms/step
# joy : 0.9994970560073853
#
#
# im grabbing a minute to post i feel greedy wrong
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 87ms/step
# anger : 0.998555600643158
#
#
# He was speechles when he found out he was accepted to this new job
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# love : 0.5522423982620239
#
#
# This is outrageous, how can you talk like that?
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 68ms/step
# anger : 0.9783509373664856
#
#
# I feel like im all alone in this world
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 77ms/step
# sadness : 0.9873003363609314
#
#
# He is really sweet and caring
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 83ms/step
# love : 0.9485644698143005
#
#
# You made me very crazy
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# joy : 0.5749815702438354
#
#
# i am ever feeling nostalgic about the fireplace i will know that it is still on the property
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# love : 0.9954647421836853
#
#
# i am feeling grouchy
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 101ms/step
# anger : 0.9936113953590393
#
#
# He hates you
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 69ms/step
# anger : 0.9801282286643982

# %% [markdown]
# ## Save the Model and Files

# %%
model.save('model1.h5')

# Save the LabelEncoder
with open('lb1.pkl', 'wb') as f:
    pickle.dump(lb, f)

# Save vocabulary size and max length
vocab_info = {'vocab_size': 11000, 'max_len': 300}
with open('vocab_info.pkl', 'wb') as f:
    pickle.dump(vocab_info, f)
# Out:
# C:\Users\Tast\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# use this version
import tensorflow
import keras
print(keras.__version__)
print(tensorflow.__version__)
# Out:
# 2.15.0
# 2.15.0
